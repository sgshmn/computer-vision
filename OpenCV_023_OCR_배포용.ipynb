# %% [markdown]
# <img src="./lecture_image/00_title.png">

# %% [markdown]
# <table border=1 width=100%>
#     <tr><td style="border: 1px solid black; width:600px; height:30px; text-align: center;"><font size=4 color=blue><b>[23차시] 학습목표</b></font></td></tr>
#     <tr><td style="border: 1px solid black; text-align: left;"><font size=3>
# ○ OCR 방법에 대해 이해할 수 있다<br><br>
# ○ Tessaract를 이용하여 문자를 인식할 수 있다<br><br>
# ○ EasyOCR 이용한 문자를 인식할 수 있다<br><br>
# ○ 기타 OCR 라이브러리를 사용하여 문자을 인식할 수 있다
#         </font></td></tr>
# </table>

# %% [markdown]
# # OCR
#
# - 참고 : https://meissa.tistory.com/80?category=962022

# %% [markdown]
# ## 개념
#
# - OCR  =Text detection + Text recognition
#
# <img src="./lecture_image/23_ocr01.png" width=70%>
#
#   - Text detection : Object detection의 문자 찾아내기 확장 버전(Segmentation 및 문자특성 고려)
#     - 이미지 내에서 문자를 검출해낼 때엔 검출하기 위한 최소 단위를 설정
#     - 단어 단위의 탐지 : Object detection의 Regression기반의 Detection방법
#       - Anchor를 정의하고 단어의 유무, Bounding box의 크기를 추정해서 단어를 찾음
#       - (예) TextBoxes 방법
#     - 글자 단위의 방식 : 글자인 영역을 Segmentation하는 방법으로 접근
#       - (예) PixelLink 방법
#     - 두 가지 방법을 모두 활용한 방법이 있음
#       - CRAFT : Character 단위로 문자의 위치를 찾아낸 뒤 이를 연결하는 방식을 Segmentation기반으로 구현한 방법
#
#       - PMTD(Pyramid Mask Text Detector) : Mask-RCNN으로 Text영역 검출 → 단어의 사각형 배치 특성을 반영한 피라미드 형태의 Score map을 활용하여 기존의 부정확한 Mask 영역을 보완
#         - Mask-RCNN의 경우 단어 영역이 Box head에 의해 빨간색으로 잡히면 우측 처럼 boundary를 모두 Text 영역으로 잡지만, PMTD는 이를 보완하여 전체 Text 영역을 검출
#
# <img src="./lecture_image/23_ocr03.png" width=60%>
#
#   - Text recognition : 검출된 영역의 문자가 무엇인지를 인식해 내는 과정
#     - Unsegmented Data : 분리에 드는 비용이 비싸거나 어려워 Segmentation이 되어있지 않은 데이터
#       - 특징 : segment되어 있지 않은 하위데이터들끼리 시퀀스(sequence)를 이루고 있다는 점
#     - CRNN : CNN으로 문자의 특성을 검출하고 Map-To-Sequence로 변환한 후에 Bidirectional LSTM으로 문자를 인식하는 방법

# %% [markdown]
# ## Tessaract
# - 1980년대 최초로 개발된 OCR 알고리즘 중 하나
#
#
# - 다운로드 : https://github.com/UB-Mannheim/tesseract/wiki
#
#
# - tesseract-ocr-w64-setup-v5.0.0-alpha.20201127.exe 파일 다운로드 및 설치
#
# - Additional language data 체크

# %%
# !pip install pytesseract
# Out:
# Collecting pytesseract
#   Downloading pytesseract-0.3.10-py3-none-any.whl (14 kB)
# Requirement already satisfied: packaging>=21.3 in d:\anaconda3\envs\yolov7\lib\site-packages (from pytesseract) (21.3)
# Requirement already satisfied: Pillow>=8.0.0 in d:\anaconda3\envs\yolov7\lib\site-packages (from pytesseract) (9.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in d:\anaconda3\envs\yolov7\lib\site-packages (from packaging>=21.3->pytesseract) (3.0.9)
# Installing collected packages: pytesseract
# Successfully installed pytesseract-0.3.10

# %%
#실습

# %%
#실습

# %%
#실습

# %%
#실습
# Out:
#
#
# Life is a journey,
# not a guided tour.
#
# - Anonymous -

# %% [markdown]
# ### 한글 이미지 인식

# %%
#실습

# %%
#실습
# Out:
# 소년
#
# 여기저기서 단풍잎 같은 슬픈 가을이 뚝뚝 떨어진다. 단풍잎
# 떨어져 나온 자리마다 봄을 마련해 놓고 나못가지 위에 하늘이
# 펼쳐 있다. 가만히 하늘을 들여다보려면 눈썸에 파란 물감이
# 든다. 두 손으로 따뜻한 볼을 쓸어 보면 손바닥에도 파란 물감
# 이 묻어난다. 다시 손바닥을 들여다본다. 손금에는 맑은 강물
# 이 흐르고, 맑은 강물이 흐르고, 강물 속에는 사랑처럼 슬픈 얼
# 굴ㅡ- 아름다운 순이의 얼굴이 어린다. 소년은 황홀히 눈을
# 감아 본다. 그래도 맑은 강물은 흘러 사랑처럼 슬픈 얼굴--
# 아름다운 순이의 얼굴은 어린다.

# %% [markdown]
# ### 포스터 한글 이미지 인식

# %%
#실습

# %%
#실습
# Out:
# 자연을 대출하면
# 미래는 파산합니다

# %% [markdown]
# ### 번호판 인식

# %%
#실습

# %%
#실습
# Out:
# 527 3108.|

# %%
#실습

# %%
#실습
# Out:
# | 52가 3108

# %% [markdown]
# ## EasyOCR
# - 문자영역 인식, 문자 인식을 쉽게 할 수 있게 하는 파이썬 라이브러리
# - 간단하고 직관적
# - 80개 이상의 언어를 지원
# - 문자 추출은 CRAFT를 문자 인식은 CRNN을 사용
#
#
# - 수행 결과로 텍스트의 바운딩 박스 좌표와 읽은 문자를 반환
#
#
# - 참고 : https://github.com/JaidedAI/EasyOCR

# %%
#!pip uninstall opencv-python
# !pip install opencv-python==4.5.4.60 easyocr
# Out:
# Collecting opencv-python==4.5.4.60
#   Downloading opencv_python-4.5.4.60-cp37-cp37m-win_amd64.whl (35.1 MB)
#      --------------------------------------- 35.1/35.1 MB 11.3 MB/s eta 0:00:00
# Collecting easyocr
#   Downloading easyocr-1.6.2-py3-none-any.whl (2.9 MB)
#      ---------------------------------------- 2.9/2.9 MB 13.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.14.5 in c:\anaconda3\envs\opencv2\lib\site-packages (from opencv-python==4.5.4.60) (1.21.5)
# Collecting Shapely
#   Downloading Shapely-1.8.5-cp37-cp37m-win_amd64.whl (1.3 MB)
#      ---------------------------------------- 1.3/1.3 MB 7.7 MB/s eta 0:00:00
# Collecting pyclipper
#   Downloading pyclipper-1.3.0.post3-cp37-cp37m-win_amd64.whl (94 kB)
#      ---------------------------------------- 94.3/94.3 kB 5.3 MB/s eta 0:00:00
# Requirement already satisfied: scipy in c:\anaconda3\envs\opencv2\lib\site-packages (from easyocr) (1.7.3)
# Collecting python-bidi
#   Downloading python_bidi-0.4.2-py2.py3-none-any.whl (30 kB)
# Collecting scikit-image
#   Downloading scikit_image-0.19.3-cp37-cp37m-win_amd64.whl (12.1 MB)
#      --------------------------------------- 12.1/12.1 MB 10.6 MB/s eta 0:00:00
# Collecting PyYAML
#   Downloading PyYAML-6.0-cp37-cp37m-win_amd64.whl (153 kB)
#      -------------------------------------- 153.2/153.2 kB 9.5 MB/s eta 0:00:00
# Collecting ninja
#   Downloading ninja-1.10.2.4-py2.py3-none-win_amd64.whl (293 kB)
#      -------------------------------------- 293.9/293.9 kB 8.9 MB/s eta 0:00:00
# Requirement already satisfied: torch in c:\anaconda3\envs\opencv2\lib\site-packages (from easyocr) (1.12.1)
# Requirement already satisfied: torchvision>=0.5 in c:\anaconda3\envs\opencv2\lib\site-packages (from easyocr) (0.13.1)
# Requirement already satisfied: Pillow in c:\anaconda3\envs\opencv2\lib\site-packages (from easyocr) (9.2.0)
# Collecting opencv-python-headless<=4.5.4.60
#   Downloading opencv_python_headless-4.5.4.60-cp37-cp37m-win_amd64.whl (35.0 MB)
#      --------------------------------------- 35.0/35.0 MB 11.1 MB/s eta 0:00:00
# Requirement already satisfied: requests in c:\anaconda3\envs\opencv2\lib\site-packages (from torchvision>=0.5->easyocr) (2.28.1)
# Requirement already satisfied: typing-extensions in c:\anaconda3\envs\opencv2\lib\site-packages (from torchvision>=0.5->easyocr) (4.3.0)
# Requirement already satisfied: six in c:\anaconda3\envs\opencv2\lib\site-packages (from python-bidi->easyocr) (1.16.0)
# Collecting networkx>=2.2
#   Downloading networkx-2.6.3-py3-none-any.whl (1.9 MB)
#      ---------------------------------------- 1.9/1.9 MB 11.2 MB/s eta 0:00:00
# Collecting tifffile>=2019.7.26
#   Downloading tifffile-2021.11.2-py3-none-any.whl (178 kB)
#      -------------------------------------- 178.9/178.9 kB 5.4 MB/s eta 0:00:00
# Collecting PyWavelets>=1.1.1
#   Downloading PyWavelets-1.3.0-cp37-cp37m-win_amd64.whl (4.2 MB)
#      ---------------------------------------- 4.2/4.2 MB 14.7 MB/s eta 0:00:00
# Collecting imageio>=2.4.1
#   Downloading imageio-2.22.1-py3-none-any.whl (3.4 MB)
#      ---------------------------------------- 3.4/3.4 MB 10.2 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in c:\anaconda3\envs\opencv2\lib\site-packages (from scikit-image->easyocr) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\anaconda3\envs\opencv2\lib\site-packages (from packaging>=20.0->scikit-image->easyocr) (3.0.9)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\anaconda3\envs\opencv2\lib\site-packages (from requests->torchvision>=0.5->easyocr) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in c:\anaconda3\envs\opencv2\lib\site-packages (from requests->torchvision>=0.5->easyocr) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\anaconda3\envs\opencv2\lib\site-packages (from requests->torchvision>=0.5->easyocr) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\anaconda3\envs\opencv2\lib\site-packages (from requests->torchvision>=0.5->easyocr) (2022.9.14)
# Installing collected packages: pyclipper, ninja, tifffile, Shapely, PyYAML, PyWavelets, python-bidi, opencv-python-headless, opencv-python, networkx, imageio, scikit-image, easyocr
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.6.0.66
#     Uninstalling opencv-python-4.6.0.66:
#       Successfully uninstalled opencv-python-4.6.0.66
# Successfully installed PyWavelets-1.3.0 PyYAML-6.0 Shapely-1.8.5 easyocr-1.6.2 imageio-2.22.1 networkx-2.6.3 ninja-1.10.2.4 opencv-python-4.5.4.60 opencv-python-headless-4.5.4.60 pyclipper-1.3.0.post3 python-bidi-0.4.2 scikit-image-0.19.3 tifffile-2021.11.2
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\gjaischool-56\appdata\roaming\python\python37\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\anaconda3\envs\opencv2\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\gjaischool-56\appdata\roaming\python\python37\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\anaconda3\envs\opencv2\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\gjaischool-56\appdata\roaming\python\python37\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\anaconda3\envs\opencv2\lib\site-packages)
#     WARNING: Ignoring invalid distribution -rotobuf (c:\users\gjaischool-56\appdata\roaming\python\python37\site-packages)
#     WARNING: Ignoring invalid distribution -pencv-python (c:\anaconda3\envs\opencv2\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\anaconda3\envs\opencv2\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\anaconda3\envs\opencv2\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\anaconda3\envs\opencv2\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\anaconda3\envs\opencv2\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\anaconda3\envs\opencv2\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\anaconda3\envs\opencv2\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\anaconda3\envs\opencv2\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\anaconda3\envs\opencv2\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\anaconda3\envs\opencv2\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\anaconda3\envs\opencv2\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\anaconda3\envs\opencv2\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\anaconda3\envs\opencv2\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\anaconda3\envs\opencv2\lib\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# deepface 0.0.75 requires opencv-python>=4.5.5.64, but you have opencv-python 4.5.4.60 which is incompatible.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\gjaischool-56\appdata\roaming\python\python37\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\anaconda3\envs\opencv2\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\gjaischool-56\appdata\roaming\python\python37\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\anaconda3\envs\opencv2\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\gjaischool-56\appdata\roaming\python\python37\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\anaconda3\envs\opencv2\lib\site-packages)

# %%
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %%
import cv2
import matplotlib.pyplot as plt
import easyocr

# %%
img = cv2.imread('images/car4.jfif')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img)
plt.axis('off')
plt.show()

# 리더기 설정 (언어)
reader = easyocr.Reader(['ko', 'en'])

result = reader.readtext('images/car4.jfif')

result
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# Downloading detection model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Downloading recognition model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.1% Complete
# [([[62, 54], [136, 54], [136, 78], [62, 78]], '부산   금정', 0.9787972010668372),
#  ([[44, 86], [68, 86], [68, 110], [44, 110]], '라', 0.9989465866557943),
#  ([[65, 73], [159, 73], [159, 113], [65, 113]], '4550', 0.9999988675117493)]

# %%
img = cv2.imread('images/nature.png')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img)
plt.axis('off')
plt.show()

# 리더기 설정 (언어)
reader = easyocr.Reader(['ko', 'en'])

result = reader.readtext('images/nature.png')

result
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# [([[69, 165], [153, 165], [153, 183], [69, 183]],
#   '자연올 대출하면',
#   0.681642453907865),
#  ([[63, 183], [159, 183], [159, 199], [63, 199]],
#   '미래는 파산갑니다',
#   0.38144644652827203)]

# %% [markdown]
# ## PaddleOCR
#
# - 참고
#   - https://learnopencv.com/optical-character-recognition-using-paddleocr/?ck_subscriber_id=1390420859
#   - https://github.com/PaddlePaddle/PaddleOCR
#
#
# - 텍스트 감지, 텍스트 방향 분류기 및 텍스트 인식을 제공
# - PP-OCR 및 SRN, NRTR 등과 같은 최신 알고리즘을 포함하여 툴킷에 다양한 모델을 제공
# - 80 개 이상의 언어를 지원
#
#
# <img src="./lecture_image/23_paddleocr1.png" width=80%>

# %% [markdown]
# - 설치

# %%
# !conda create -n paddleocr python==3.7

# %%
# !activate paddleocr

# %%
# !git clone https://gitee.com/paddlepaddle/PaddleOCR.git
# Out:
# Cloning into 'PaddleOCR'...
# Updating files:  56% (858/1519)
# Updating files:  57% (866/1519)
# Updating files:  58% (882/1519)
# Updating files:  59% (897/1519)
# Updating files:  60% (912/1519)
# Updating files:  61% (927/1519)
# Updating files:  62% (942/1519)
# Updating files:  63% (957/1519)
# Updating files:  64% (973/1519)
# Updating files:  65% (988/1519)
# Updating files:  66% (1003/1519)
# Updating files:  67% (1018/1519)
# Updating files:  68% (1033/1519)
# Updating files:  69% (1049/1519)
# Updating files:  70% (1064/1519)
# Updating files:  71% (1079/1519)
# Updating files:  72% (1094/1519)
# Updating files:  73% (1109/1519)
# Updating files:  74% (1125/1519)
# Updating files:  75% (1140/1519)
# Updating files:  76% (1155/1519)
# Updating files:  77% (1170/1519)
# Updating files:  78% (1185/1519)
# Updating files:  79% (1201/1519)
# Updating files:  80% (1216/1519)
# Updating files:  81% (1231/1519)
# Updating files:  82% (1246/1519)
# Updating files:  83% (1261/1519)
# Updating files:  84% (1276/1519)
# Updating files:  85% (1292/1519)
# Updating files:  86% (1307/1519)
# Updating files:  87% (1322/1519)
# Updating files:  88% (1337/1519)
# Updating files:  89% (1352/1519)
# Updating files:  90% (1368/1519)
# Updating files:  91% (1383/1519)
# Updating files:  92% (1398/1519)
# Updating files:  93% (1413/1519)
# Updating files:  94% (1428/1519)
# Updating files:  95% (1444/1519)
# Updating files:  96% (1459/1519)
# Updating files:  97% (1474/1519)
# Updating files:  98% (1489/1519)
# Updating files:  99% (1504/1519)
# Updating files: 100% (1519/1519)
# Updating files: 100% (1519/1519), done.

# %%
# !pip install -r ./PaddleOCR/requirements.txt
# Out:
# Collecting shapely
#   Downloading Shapely-1.8.4-cp37-cp37m-win_amd64.whl (1.3 MB)
#      ---------------------------------------- 1.3/1.3 MB 9.3 MB/s eta 0:00:00
# Collecting scikit-image
#   Downloading scikit_image-0.19.3-cp37-cp37m-win_amd64.whl (12.1 MB)
#      --------------------------------------- 12.1/12.1 MB 11.3 MB/s eta 0:00:00
# Collecting imgaug
#   Using cached imgaug-0.4.0-py2.py3-none-any.whl (948 kB)
# Collecting pyclipper
#   Downloading pyclipper-1.3.0.post3-cp37-cp37m-win_amd64.whl (94 kB)
#      ---------------------------------------- 94.3/94.3 kB 5.6 MB/s eta 0:00:00
# Collecting lmdb
#   Downloading lmdb-1.3.0-cp37-cp37m-win_amd64.whl (105 kB)
#      -------------------------------------- 105.6/105.6 kB 6.0 MB/s eta 0:00:00
# Collecting tqdm
#   Downloading tqdm-4.64.1-py2.py3-none-any.whl (78 kB)
#      ---------------------------------------- 78.5/78.5 kB 4.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy in c:\users\egeg\appdata\roaming\python\python37\site-packages (from -r ./PaddleOCR/requirements.txt (line 7)) (1.19.3)
# Collecting visualdl
#   Using cached visualdl-2.4.0-py3-none-any.whl (4.9 MB)
# Collecting rapidfuzz
#   Downloading rapidfuzz-2.8.0-cp37-cp37m-win_amd64.whl (1.2 MB)
#      ---------------------------------------- 1.2/1.2 MB 10.7 MB/s eta 0:00:00
# Collecting opencv-contrib-python
#   Using cached opencv_contrib_python-4.6.0.66-cp36-abi3-win_amd64.whl (42.5 MB)
# Collecting cython
#   Using cached Cython-0.29.32-py2.py3-none-any.whl (986 kB)
# Requirement already satisfied: lxml in d:\anaconda3\envs\paddleocr\lib\site-packages (from -r ./PaddleOCR/requirements.txt (line 12)) (4.9.1)
# Collecting premailer
#   Using cached premailer-3.10.0-py2.py3-none-any.whl (19 kB)
# Collecting openpyxl
#   Using cached openpyxl-3.0.10-py2.py3-none-any.whl (242 kB)
# Collecting attrdict
#   Using cached attrdict-2.0.1-py2.py3-none-any.whl (9.9 kB)
# Collecting pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0
#   Using cached Pillow-9.2.0-cp37-cp37m-win_amd64.whl (3.3 MB)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\egeg\appdata\roaming\python\python37\site-packages (from scikit-image->-r ./PaddleOCR/requirements.txt (line 2)) (1.4.1)
# Collecting tifffile>=2019.7.26
#   Downloading tifffile-2021.11.2-py3-none-any.whl (178 kB)
#      ------------------------------------- 178.9/178.9 kB 11.2 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in d:\anaconda3\envs\paddleocr\lib\site-packages (from scikit-image->-r ./PaddleOCR/requirements.txt (line 2)) (21.3)
# Collecting PyWavelets>=1.1.1
#   Downloading PyWavelets-1.3.0-cp37-cp37m-win_amd64.whl (4.2 MB)
#      ---------------------------------------- 4.2/4.2 MB 11.1 MB/s eta 0:00:00
# Collecting networkx>=2.2
#   Downloading networkx-2.6.3-py3-none-any.whl (1.9 MB)
#      ---------------------------------------- 1.9/1.9 MB 11.1 MB/s eta 0:00:00
# Collecting imageio>=2.4.1
#   Downloading imageio-2.21.3-py3-none-any.whl (3.4 MB)
#      ---------------------------------------- 3.4/3.4 MB 11.3 MB/s eta 0:00:00
# Requirement already satisfied: six in c:\users\egeg\appdata\roaming\python\python37\site-packages (from imgaug->-r ./PaddleOCR/requirements.txt (line 3)) (1.15.0)
# Requirement already satisfied: opencv-python in c:\users\egeg\appdata\roaming\python\python37\site-packages (from imgaug->-r ./PaddleOCR/requirements.txt (line 3)) (4.6.0.66)
# Requirement already satisfied: matplotlib in c:\users\egeg\appdata\roaming\python\python37\site-packages (from imgaug->-r ./PaddleOCR/requirements.txt (line 3)) (3.3.2)
# Requirement already satisfied: colorama in d:\anaconda3\envs\paddleocr\lib\site-packages (from tqdm->-r ./PaddleOCR/requirements.txt (line 6)) (0.4.5)
# Collecting pandas
#   Using cached pandas-1.3.5-cp37-cp37m-win_amd64.whl (10.0 MB)
# Requirement already satisfied: protobuf>=3.11.0 in c:\users\egeg\appdata\roaming\python\python37\site-packages (from visualdl->-r ./PaddleOCR/requirements.txt (line 8)) (3.19.4)
# Collecting bce-python-sdk
#   Using cached bce_python_sdk-0.8.74-py3-none-any.whl (204 kB)
# Collecting requests
#   Using cached requests-2.28.1-py3-none-any.whl (62 kB)
# Collecting Flask-Babel>=1.0.0
#   Using cached Flask_Babel-2.0.0-py3-none-any.whl (9.3 kB)
# Collecting flask>=1.1.1
#   Using cached Flask-2.2.2-py3-none-any.whl (101 kB)
# Collecting jarowinkler<2.0.0,>=1.2.0
#   Downloading jarowinkler-1.2.1-cp37-cp37m-win_amd64.whl (62 kB)
#      ---------------------------------------- 62.4/62.4 kB ? eta 0:00:00
# Collecting cssselect
#   Using cached cssselect-1.1.0-py2.py3-none-any.whl (16 kB)
# Collecting cssutils
#   Using cached cssutils-2.6.0-py3-none-any.whl (399 kB)
# Requirement already satisfied: cachetools in c:\users\egeg\appdata\roaming\python\python37\site-packages (from premailer->-r ./PaddleOCR/requirements.txt (line 13)) (5.2.0)
# Collecting et-xmlfile
#   Using cached et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Collecting itsdangerous>=2.0
#   Using cached itsdangerous-2.1.2-py3-none-any.whl (15 kB)
# Requirement already satisfied: importlib-metadata>=3.6.0 in d:\anaconda3\envs\paddleocr\lib\site-packages (from flask>=1.1.1->visualdl->-r ./PaddleOCR/requirements.txt (line 8)) (4.12.0)
# Collecting click>=8.0
#   Using cached click-8.1.3-py3-none-any.whl (96 kB)
# Requirement already satisfied: Jinja2>=3.0 in d:\anaconda3\envs\paddleocr\lib\site-packages (from flask>=1.1.1->visualdl->-r ./PaddleOCR/requirements.txt (line 8)) (3.1.2)
# Collecting Werkzeug>=2.2.2
#   Using cached Werkzeug-2.2.2-py3-none-any.whl (232 kB)
# Collecting Babel>=2.3
#   Using cached Babel-2.10.3-py3-none-any.whl (9.5 MB)
# Collecting pytz
#   Downloading pytz-2022.2.1-py2.py3-none-any.whl (500 kB)
#      ------------------------------------- 500.6/500.6 kB 10.4 MB/s eta 0:00:00
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in d:\anaconda3\envs\paddleocr\lib\site-packages (from packaging>=20.0->scikit-image->-r ./PaddleOCR/requirements.txt (line 2)) (3.0.9)
# Collecting future>=0.6.0
#   Using cached future-0.18.2-py3-none-any.whl
# Collecting pycryptodome>=3.8.0
#   Using cached pycryptodome-3.15.0-cp35-abi3-win_amd64.whl (1.9 MB)
# Requirement already satisfied: certifi>=2020.06.20 in d:\anaconda3\envs\paddleocr\lib\site-packages (from matplotlib->imgaug->-r ./PaddleOCR/requirements.txt (line 3)) (2022.6.15)
# Collecting cycler>=0.10
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: python-dateutil>=2.1 in d:\anaconda3\envs\paddleocr\lib\site-packages (from matplotlib->imgaug->-r ./PaddleOCR/requirements.txt (line 3)) (2.8.2)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.4-cp37-cp37m-win_amd64.whl (54 kB)
#      ---------------------------------------- 54.9/54.9 kB ? eta 0:00:00
# Collecting charset-normalizer<3,>=2
#   Downloading charset_normalizer-2.1.1-py3-none-any.whl (39 kB)
# Collecting urllib3<1.27,>=1.21.1
#   Downloading urllib3-1.26.12-py2.py3-none-any.whl (140 kB)
#      -------------------------------------- 140.4/140.4 kB 8.7 MB/s eta 0:00:00
# Collecting idna<4,>=2.5
#   Using cached idna-3.3-py3-none-any.whl (61 kB)
# Requirement already satisfied: zipp>=0.5 in d:\anaconda3\envs\paddleocr\lib\site-packages (from importlib-metadata>=3.6.0->flask>=1.1.1->visualdl->-r ./PaddleOCR/requirements.txt (line 8)) (3.8.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in d:\anaconda3\envs\paddleocr\lib\site-packages (from importlib-metadata>=3.6.0->flask>=1.1.1->visualdl->-r ./PaddleOCR/requirements.txt (line 8)) (4.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\anaconda3\envs\paddleocr\lib\site-packages (from Jinja2>=3.0->flask>=1.1.1->visualdl->-r ./PaddleOCR/requirements.txt (line 8)) (2.1.1)
# Installing collected packages: pytz, pyclipper, lmdb, Werkzeug, urllib3, tqdm, tifffile, shapely, PyWavelets, pycryptodome, pillow, opencv-contrib-python, networkx, kiwisolver, jarowinkler, itsdangerous, idna, future, et-xmlfile, cython, cycler, cssselect, charset-normalizer, Babel, attrdict, requests, rapidfuzz, pandas, openpyxl, imageio, cssutils, click, bce-python-sdk, scikit-image, premailer, flask, imgaug, Flask-Babel, visualdl
# Successfully installed Babel-2.10.3 Flask-Babel-2.0.0 PyWavelets-1.3.0 Werkzeug-2.2.2 attrdict-2.0.1 bce-python-sdk-0.8.74 charset-normalizer-2.1.1 click-8.1.3 cssselect-1.1.0 cssutils-2.6.0 cycler-0.11.0 cython-0.29.32 et-xmlfile-1.1.0 flask-2.2.2 future-0.18.2 idna-3.3 imageio-2.21.3 imgaug-0.4.0 itsdangerous-2.1.2 jarowinkler-1.2.1 kiwisolver-1.4.4 lmdb-1.3.0 networkx-2.6.3 opencv-contrib-python-4.6.0.66 openpyxl-3.0.10 pandas-1.3.5 pillow-9.2.0 premailer-3.10.0 pyclipper-1.3.0.post3 pycryptodome-3.15.0 pytz-2022.2.1 rapidfuzz-2.8.0 requests-2.28.1 scikit-image-0.19.3 shapely-1.8.4 tifffile-2021.11.2 tqdm-4.64.1 urllib3-1.26.12 visualdl-2.4.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorboard 2.9.1 requires absl-py>=0.4, which is not installed.
# imageai 2.1.6 requires pillow==7.0.0, but you have pillow 9.2.0 which is incompatible.

# %%
# !pip install paddlepaddle-gpu paddleocr
# !pip install paddlepaddle paddleocr
# Out:
# Collecting paddlepaddle
#   Downloading paddlepaddle-2.3.2-cp37-cp37m-win_amd64.whl (64.3 MB)
#      ---------------------------------------- 64.3/64.3 MB 9.9 MB/s eta 0:00:00
# Collecting paddleocr
#   Using cached paddleocr-2.6.0.1-py3-none-any.whl (389 kB)
# Requirement already satisfied: protobuf<=3.20.0,>=3.1.0 in c:\users\egeg\appdata\roaming\python\python37\site-packages (from paddlepaddle) (3.19.4)
# Requirement already satisfied: numpy>=1.13 in c:\users\egeg\appdata\roaming\python\python37\site-packages (from paddlepaddle) (1.19.3)
# Collecting astor
#   Using cached astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Requirement already satisfied: Pillow in d:\anaconda3\envs\paddleocr\lib\site-packages (from paddlepaddle) (9.2.0)
# Requirement already satisfied: decorator in d:\anaconda3\envs\paddleocr\lib\site-packages (from paddlepaddle) (5.1.1)
# Collecting paddle-bfloat==0.1.7
#   Downloading paddle_bfloat-0.1.7-cp37-cp37m-win_amd64.whl (40 kB)
#      ---------------------------------------- 40.6/40.6 kB ? eta 0:00:00
# Requirement already satisfied: six in c:\users\egeg\appdata\roaming\python\python37\site-packages (from paddlepaddle) (1.15.0)
# Requirement already satisfied: requests>=2.20.0 in d:\anaconda3\envs\paddleocr\lib\site-packages (from paddlepaddle) (2.28.1)
# Requirement already satisfied: opt-einsum==3.3.0 in c:\users\egeg\appdata\roaming\python\python37\site-packages (from paddlepaddle) (3.3.0)
# Requirement already satisfied: visualdl in d:\anaconda3\envs\paddleocr\lib\site-packages (from paddleocr) (2.4.0)
# Requirement already satisfied: premailer in d:\anaconda3\envs\paddleocr\lib\site-packages (from paddleocr) (3.10.0)
# Requirement already satisfied: opencv-python in c:\users\egeg\appdata\roaming\python\python37\site-packages (from paddleocr) (4.6.0.66)
# Requirement already satisfied: openpyxl in d:\anaconda3\envs\paddleocr\lib\site-packages (from paddleocr) (3.0.10)
# Requirement already satisfied: scikit-image in d:\anaconda3\envs\paddleocr\lib\site-packages (from paddleocr) (0.19.3)
# Requirement already satisfied: opencv-contrib-python in d:\anaconda3\envs\paddleocr\lib\site-packages (from paddleocr) (4.6.0.66)
# Requirement already satisfied: attrdict in d:\anaconda3\envs\paddleocr\lib\site-packages (from paddleocr) (2.0.1)
# Requirement already satisfied: lmdb in d:\anaconda3\envs\paddleocr\lib\site-packages (from paddleocr) (1.3.0)
# Requirement already satisfied: imgaug in d:\anaconda3\envs\paddleocr\lib\site-packages (from paddleocr) (0.4.0)
# Requirement already satisfied: lxml in d:\anaconda3\envs\paddleocr\lib\site-packages (from paddleocr) (4.9.1)
# Requirement already satisfied: pyclipper in d:\anaconda3\envs\paddleocr\lib\site-packages (from paddleocr) (1.3.0.post3)
# Requirement already satisfied: rapidfuzz in d:\anaconda3\envs\paddleocr\lib\site-packages (from paddleocr) (2.8.0)
# Requirement already satisfied: shapely in d:\anaconda3\envs\paddleocr\lib\site-packages (from paddleocr) (1.8.4)
# Requirement already satisfied: cython in d:\anaconda3\envs\paddleocr\lib\site-packages (from paddleocr) (0.29.32)
# Requirement already satisfied: tqdm in d:\anaconda3\envs\paddleocr\lib\site-packages (from paddleocr) (4.64.1)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda3\envs\paddleocr\lib\site-packages (from requests>=2.20.0->paddlepaddle) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda3\envs\paddleocr\lib\site-packages (from requests>=2.20.0->paddlepaddle) (2022.6.15)
# Requirement already satisfied: charset-normalizer<3,>=2 in d:\anaconda3\envs\paddleocr\lib\site-packages (from requests>=2.20.0->paddlepaddle) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\anaconda3\envs\paddleocr\lib\site-packages (from requests>=2.20.0->paddlepaddle) (1.26.12)
# Requirement already satisfied: imageio in d:\anaconda3\envs\paddleocr\lib\site-packages (from imgaug->paddleocr) (2.21.3)
# Requirement already satisfied: scipy in c:\users\egeg\appdata\roaming\python\python37\site-packages (from imgaug->paddleocr) (1.4.1)
# Requirement already satisfied: matplotlib in c:\users\egeg\appdata\roaming\python\python37\site-packages (from imgaug->paddleocr) (3.3.2)
# Requirement already satisfied: tifffile>=2019.7.26 in d:\anaconda3\envs\paddleocr\lib\site-packages (from scikit-image->paddleocr) (2021.11.2)
# Requirement already satisfied: PyWavelets>=1.1.1 in d:\anaconda3\envs\paddleocr\lib\site-packages (from scikit-image->paddleocr) (1.3.0)
# Requirement already satisfied: networkx>=2.2 in d:\anaconda3\envs\paddleocr\lib\site-packages (from scikit-image->paddleocr) (2.6.3)
# Requirement already satisfied: packaging>=20.0 in d:\anaconda3\envs\paddleocr\lib\site-packages (from scikit-image->paddleocr) (21.3)
# Requirement already satisfied: et-xmlfile in d:\anaconda3\envs\paddleocr\lib\site-packages (from openpyxl->paddleocr) (1.1.0)
# Requirement already satisfied: cssutils in d:\anaconda3\envs\paddleocr\lib\site-packages (from premailer->paddleocr) (2.6.0)
# Requirement already satisfied: cachetools in c:\users\egeg\appdata\roaming\python\python37\site-packages (from premailer->paddleocr) (5.2.0)
# Requirement already satisfied: cssselect in d:\anaconda3\envs\paddleocr\lib\site-packages (from premailer->paddleocr) (1.1.0)
# Requirement already satisfied: jarowinkler<2.0.0,>=1.2.0 in d:\anaconda3\envs\paddleocr\lib\site-packages (from rapidfuzz->paddleocr) (1.2.1)
# Requirement already satisfied: colorama in d:\anaconda3\envs\paddleocr\lib\site-packages (from tqdm->paddleocr) (0.4.5)
# Requirement already satisfied: bce-python-sdk in d:\anaconda3\envs\paddleocr\lib\site-packages (from visualdl->paddleocr) (0.8.74)
# Requirement already satisfied: Flask-Babel>=1.0.0 in d:\anaconda3\envs\paddleocr\lib\site-packages (from visualdl->paddleocr) (2.0.0)
# Requirement already satisfied: pandas in d:\anaconda3\envs\paddleocr\lib\site-packages (from visualdl->paddleocr) (1.3.5)
# Requirement already satisfied: flask>=1.1.1 in d:\anaconda3\envs\paddleocr\lib\site-packages (from visualdl->paddleocr) (2.2.2)
# Requirement already satisfied: itsdangerous>=2.0 in d:\anaconda3\envs\paddleocr\lib\site-packages (from flask>=1.1.1->visualdl->paddleocr) (2.1.2)
# Requirement already satisfied: click>=8.0 in d:\anaconda3\envs\paddleocr\lib\site-packages (from flask>=1.1.1->visualdl->paddleocr) (8.1.3)
# Requirement already satisfied: Jinja2>=3.0 in d:\anaconda3\envs\paddleocr\lib\site-packages (from flask>=1.1.1->visualdl->paddleocr) (3.1.2)
# Requirement already satisfied: importlib-metadata>=3.6.0 in d:\anaconda3\envs\paddleocr\lib\site-packages (from flask>=1.1.1->visualdl->paddleocr) (4.12.0)
# Requirement already satisfied: Werkzeug>=2.2.2 in d:\anaconda3\envs\paddleocr\lib\site-packages (from flask>=1.1.1->visualdl->paddleocr) (2.2.2)
# Requirement already satisfied: Babel>=2.3 in d:\anaconda3\envs\paddleocr\lib\site-packages (from Flask-Babel>=1.0.0->visualdl->paddleocr) (2.10.3)
# Requirement already satisfied: pytz in d:\anaconda3\envs\paddleocr\lib\site-packages (from Flask-Babel>=1.0.0->visualdl->paddleocr) (2022.2.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in d:\anaconda3\envs\paddleocr\lib\site-packages (from packaging>=20.0->scikit-image->paddleocr) (3.0.9)
# Requirement already satisfied: future>=0.6.0 in d:\anaconda3\envs\paddleocr\lib\site-packages (from bce-python-sdk->visualdl->paddleocr) (0.18.2)
# Requirement already satisfied: pycryptodome>=3.8.0 in d:\anaconda3\envs\paddleocr\lib\site-packages (from bce-python-sdk->visualdl->paddleocr) (3.15.0)
# Requirement already satisfied: python-dateutil>=2.1 in d:\anaconda3\envs\paddleocr\lib\site-packages (from matplotlib->imgaug->paddleocr) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\anaconda3\envs\paddleocr\lib\site-packages (from matplotlib->imgaug->paddleocr) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in d:\anaconda3\envs\paddleocr\lib\site-packages (from matplotlib->imgaug->paddleocr) (0.11.0)
# Requirement already satisfied: zipp>=0.5 in d:\anaconda3\envs\paddleocr\lib\site-packages (from importlib-metadata>=3.6.0->flask>=1.1.1->visualdl->paddleocr) (3.8.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in d:\anaconda3\envs\paddleocr\lib\site-packages (from importlib-metadata>=3.6.0->flask>=1.1.1->visualdl->paddleocr) (4.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\anaconda3\envs\paddleocr\lib\site-packages (from Jinja2>=3.0->flask>=1.1.1->visualdl->paddleocr) (2.1.1)
# Installing collected packages: paddle-bfloat, astor, paddlepaddle, paddleocr
# Successfully installed astor-0.8.1 paddle-bfloat-0.1.7 paddleocr-2.6.0.1 paddlepaddle-2.3.2
#   WARNING: The script fleetrun.exe is installed in 'C:\Users\EGEG\AppData\Roaming\Python\Python37\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script paddleocr.exe is installed in 'C:\Users\EGEG\AppData\Roaming\Python\Python37\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
# !pip install jupyter

# %% [markdown]
# - 라이브러리 및 학습된 모델 로딩

# %%
import os
import cv2
import matplotlib.pyplot as plt
from paddleocr import PaddleOCR, draw_ocr

# %%
# PaddleOCR : 문자 인식 함수
# draw_ocr : 인식한 결과를 보여주는 함수

# lang : ch, en, french, german, korean, japan
ocr = PaddleOCR(use_angle_cls=True, lange='en')
# Out:
# download https://paddleocr.bj.bcebos.com/PP-OCRv3/chinese/ch_PP-OCRv3_det_infer.tar to C:\Users\gjaischool-56/.paddleocr/whl\det\ch\ch_PP-OCRv3_det_infer\ch_PP-OCRv3_det_infer.tar
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 3.83M/3.83M [00:13<00:00, 281kiB/s]
# download https://paddleocr.bj.bcebos.com/PP-OCRv3/chinese/ch_PP-OCRv3_rec_infer.tar to C:\Users\gjaischool-56/.paddleocr/whl\rec\ch\ch_PP-OCRv3_rec_infer\ch_PP-OCRv3_rec_infer.tar
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 11.9M/11.9M [00:11<00:00, 1.03MiB/s]
# [2022/10/14 09:21:29] ppocr DEBUG: Namespace(alpha=1.0, benchmark=False, beta=1.0, cls_batch_num=6, cls_image_shape='3, 48, 192', cls_model_dir='C:\\Users\\gjaischool-56/.paddleocr/whl\\cls\\ch_ppocr_mobile_v2.0_cls_infer', cls_thresh=0.9, cpu_threads=10, crop_res_save_dir='./output', det=True, det_algorithm='DB', det_db_box_thresh=0.6, det_db_score_mode='fast', det_db_thresh=0.3, det_db_unclip_ratio=1.5, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_east_score_thresh=0.8, det_fce_box_type='poly', det_limit_side_len=960, det_limit_type='max', det_model_dir='C:\\Users\\gjaischool-56/.paddleocr/whl\\det\\ch\\ch_PP-OCRv3_det_infer', det_pse_box_thresh=0.85, det_pse_box_type='quad', det_pse_min_area=16, det_pse_scale=1, det_pse_thresh=0, det_sast_nms_thresh=0.2, det_sast_polygon=False, det_sast_score_thresh=0.5, draw_img_save_dir='./inference_results', drop_score=0.5, e2e_algorithm='PGNet', e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_limit_side_len=768, e2e_limit_type='max', e2e_model_dir=None, e2e_pgnet_mode='fast', e2e_pgnet_score_thresh=0.5, e2e_pgnet_valid_set='totaltext', enable_mkldnn=False, fourier_degree=5, gpu_mem=500, help='==SUPPRESS==', image_dir=None, image_orientation=False, ir_optim=True, kie_algorithm='LayoutXLM', label_list=['0', '180'], lang='ch', lange='en', layout=True, layout_dict_path=None, layout_model_dir=None, layout_nms_threshold=0.5, layout_score_threshold=0.5, max_batch_size=10, max_text_length=25, merge_no_span_structure=True, min_subgraph_size=15, mode='structure', ocr=True, ocr_order_method=None, ocr_version='PP-OCRv3', output='./output', page_num=0, precision='fp32', process_id=0, re_model_dir=None, rec=True, rec_algorithm='SVTR_LCNet', rec_batch_num=6, rec_char_dict_path='C:\\Anaconda3\\envs\\paddleocr\\lib\\site-packages\\paddleocr\\ppocr\\utils\\ppocr_keys_v1.txt', rec_image_shape='3, 48, 320', rec_model_dir='C:\\Users\\gjaischool-56/.paddleocr/whl\\rec\\ch\\ch_PP-OCRv3_rec_infer', recovery=False, save_crop_res=False, save_log_path='./log_output/', scales=[8, 16, 32], ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ser_model_dir=None, show_log=True, sr_batch_num=1, sr_image_shape='3, 32, 128', sr_model_dir=None, structure_version='PP-Structurev2', table=True, table_algorithm='TableAttn', table_char_dict_path=None, table_max_len=488, table_model_dir=None, total_process_num=1, type='ocr', use_angle_cls=True, use_dilation=False, use_gpu=False, use_mp=False, use_npu=False, use_onnx=False, use_pdserving=False, use_space_char=True, use_tensorrt=False, use_visual_backbone=True, use_xpu=False, vis_font_path='./doc/fonts/simfang.ttf', warmup=False)

# %% [markdown]
# - 인식

# %%
# 결과를 출력하는 함수
# 문자가 들어있는 이미지, 추출결과, 폰트
def result_ocr(img_path, result):
    font = 'font/malgun.ttf'
    
    img = cv2.imread(img_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    
    # 추출한 결과로부터 값을 가져온다
    # (문자가 있는 바운딩 박스 좌표, 추출한 문자, 신뢰도)
    boxes = [line[0] for line in result[0]]
    txts = [line[1][0] for line in result[0]]
    scores = [line[1][1] for line in result[0]]
    
    # 추출한 내용을 출력
    im_show = draw_ocr(img, boxes, txts, scores, font_path=font)
    
    plt.imshow(im_show)
    plt.axis('off')

# %% [markdown]
# - 영수증 인식

# %%
img_path = 'images/receipt1.png'
result = ocr.ocr(img_path)


result_ocr(img_path, result)
# Out:
# [2022/10/14 10:10:59] ppocr DEBUG: dt_boxes num : 34, elapse : 0.11173653602600098
# [2022/10/14 10:10:59] ppocr DEBUG: cls num  : 34, elapse : 0.35089993476867676
# [2022/10/14 10:11:03] ppocr DEBUG: rec_res num  : 34, elapse : 3.5295815467834473

# %% [markdown]
# - ID 카드 인식

# %%
img_path = 'images/id-card.png'
result = ocr.ocr(img_path)


result_ocr(img_path, result)
# Out:
# [2022/10/14 10:11:56] ppocr DEBUG: dt_boxes num : 13, elapse : 0.33711910247802734
# [2022/10/14 10:11:56] ppocr DEBUG: cls num  : 13, elapse : 0.1406548023223877
# [2022/10/14 10:11:58] ppocr DEBUG: rec_res num  : 13, elapse : 1.871201515197754

# %% [markdown]
# - 손글씨 인식

# %%
img_path = 'images/hand_english.png'
result = ocr.ocr(img_path)


result_ocr(img_path, result)
# Out:
# [2022/10/14 10:12:46] ppocr DEBUG: dt_boxes num : 5, elapse : 0.6415021419525146
# [2022/10/14 10:12:46] ppocr DEBUG: cls num  : 5, elapse : 0.05704092979431152
# [2022/10/14 10:12:47] ppocr DEBUG: rec_res num  : 5, elapse : 0.4567832946777344

# %% [markdown]
# - 자동차 번호판

# %%
img_path = 'images/car_number.png'
result = ocr.ocr(img_path)


result_ocr(img_path, result)
# Out:
# [2022/10/14 10:16:16] ppocr DEBUG: dt_boxes num : 1, elapse : 0.1595776081085205
# [2022/10/14 10:16:16] ppocr DEBUG: cls num  : 1, elapse : 0.012965917587280273
# [2022/10/14 10:16:17] ppocr DEBUG: rec_res num  : 1, elapse : 0.09078860282897949

# %% [markdown]
# - 도로 표지판

# %%
img_path = 'images/load_sign.png'
result = ocr.ocr(img_path)


result_ocr(img_path, result)
# Out:
# [2022/10/14 10:16:37] ppocr DEBUG: dt_boxes num : 9, elapse : 0.42685842514038086
# [2022/10/14 10:16:37] ppocr DEBUG: cls num  : 9, elapse : 0.09971928596496582
# [2022/10/14 10:16:38] ppocr DEBUG: rec_res num  : 9, elapse : 0.817939281463623

# %% [markdown]
# - 곡선 텍스트

# %%
img_path = 'images/curved_text1.png'
result = ocr.ocr(img_path)


result_ocr(img_path, result)
# Out:
# [2022/10/14 10:17:21] ppocr DEBUG: dt_boxes num : 3, elapse : 0.4438455104827881
# [2022/10/14 10:17:21] ppocr DEBUG: cls num  : 3, elapse : 0.04288625717163086
# [2022/10/14 10:17:21] ppocr DEBUG: rec_res num  : 3, elapse : 0.31219911575317383

# %%
ocr_ko = PaddleOCR(use_angle_cls=True, lange='korean')
# Out:
# [2022/10/14 10:17:49] ppocr DEBUG: Namespace(alpha=1.0, benchmark=False, beta=1.0, cls_batch_num=6, cls_image_shape='3, 48, 192', cls_model_dir='C:\\Users\\gjaischool-56/.paddleocr/whl\\cls\\ch_ppocr_mobile_v2.0_cls_infer', cls_thresh=0.9, cpu_threads=10, crop_res_save_dir='./output', det=True, det_algorithm='DB', det_db_box_thresh=0.6, det_db_score_mode='fast', det_db_thresh=0.3, det_db_unclip_ratio=1.5, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_east_score_thresh=0.8, det_fce_box_type='poly', det_limit_side_len=960, det_limit_type='max', det_model_dir='C:\\Users\\gjaischool-56/.paddleocr/whl\\det\\ch\\ch_PP-OCRv3_det_infer', det_pse_box_thresh=0.85, det_pse_box_type='quad', det_pse_min_area=16, det_pse_scale=1, det_pse_thresh=0, det_sast_nms_thresh=0.2, det_sast_polygon=False, det_sast_score_thresh=0.5, draw_img_save_dir='./inference_results', drop_score=0.5, e2e_algorithm='PGNet', e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_limit_side_len=768, e2e_limit_type='max', e2e_model_dir=None, e2e_pgnet_mode='fast', e2e_pgnet_score_thresh=0.5, e2e_pgnet_valid_set='totaltext', enable_mkldnn=False, fourier_degree=5, gpu_mem=500, help='==SUPPRESS==', image_dir=None, image_orientation=False, ir_optim=True, kie_algorithm='LayoutXLM', label_list=['0', '180'], lang='ch', lange='korean', layout=True, layout_dict_path=None, layout_model_dir=None, layout_nms_threshold=0.5, layout_score_threshold=0.5, max_batch_size=10, max_text_length=25, merge_no_span_structure=True, min_subgraph_size=15, mode='structure', ocr=True, ocr_order_method=None, ocr_version='PP-OCRv3', output='./output', page_num=0, precision='fp32', process_id=0, re_model_dir=None, rec=True, rec_algorithm='SVTR_LCNet', rec_batch_num=6, rec_char_dict_path='C:\\Anaconda3\\envs\\paddleocr\\lib\\site-packages\\paddleocr\\ppocr\\utils\\ppocr_keys_v1.txt', rec_image_shape='3, 48, 320', rec_model_dir='C:\\Users\\gjaischool-56/.paddleocr/whl\\rec\\ch\\ch_PP-OCRv3_rec_infer', recovery=False, save_crop_res=False, save_log_path='./log_output/', scales=[8, 16, 32], ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ser_model_dir=None, show_log=True, sr_batch_num=1, sr_image_shape='3, 32, 128', sr_model_dir=None, structure_version='PP-Structurev2', table=True, table_algorithm='TableAttn', table_char_dict_path=None, table_max_len=488, table_model_dir=None, total_process_num=1, type='ocr', use_angle_cls=True, use_dilation=False, use_gpu=False, use_mp=False, use_npu=False, use_onnx=False, use_pdserving=False, use_space_char=True, use_tensorrt=False, use_visual_backbone=True, use_xpu=False, vis_font_path='./doc/fonts/simfang.ttf', warmup=False)

# %%
img_path = 'images/receipt1.jpg'
result = ocr_ko.ocr(img_path)


result_ocr(img_path, result)
# Out:
# [2022/10/14 10:20:26] ppocr DEBUG: dt_boxes num : 40, elapse : 0.5055186748504639
# [2022/10/14 10:20:26] ppocr DEBUG: cls num  : 40, elapse : 0.44149255752563477
# [2022/10/14 10:20:30] ppocr DEBUG: rec_res num  : 40, elapse : 4.005255222320557

# %% [markdown]
# ## 구글 OCR API 활용
#
# - 참고 : https://cloud.google.com/vision/docs/quickstart

# %% [markdown]
# ## Naver 클로버 OCR
#
# - 참고 : https://clova.ai/ocr?lang=ko

# %% [markdown]
# <table border=1 width=100%>
#     <tr><td style="border: 1px solid black; width:600px; height:40px; text-align: center;"><font size=4 color=blue><b>[23차시] 정리하기</b></font></td></tr>
#     <tr><td style="border: 1px solid black; text-align: left;"><font size=3>○
#         </font></td></tr>
# </table>
