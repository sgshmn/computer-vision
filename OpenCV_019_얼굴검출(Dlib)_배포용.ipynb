# %% [markdown]
# <img src="./lecture_image/00_title.png">

# %% [markdown]
# <table border=1 width=100%>
#     <tr><td style="border: 1px solid black; width:600px; height:30px; text-align: center;"><font size=4 color=blue><b>[19차시] 학습목표</b></font></td></tr>
#     <tr><td style="border: 1px solid black; text-align: left;"><font size=3>
# ○ Dlib 라이브러리를 사용할 수 있는 환경을 구축할 수 있다<br><br>
# ○ Dlib 라이브러리를 이용하여 얼굴을 검출할 수 있다 <br><br>
# ○ Dlib 라이브러리의 랜드마크를 이해하고 사용할 수 있다 </font></td></tr>
# </table>

# %% [markdown]
# # 얼굴 검출 (Dlib 라이브러리 활용)
#
# ## Dlib 개요
#
# - dlib는 얼굴영상에서 68개의 얼굴의 랜드마크 검출
# - dlib 파일 다운로드 : https://pypi.org/project/dlib/
# - 학습 데이터 모델 : http://dlib.net/files/shape_predictor_68_face_landmarks.dat.bz2
#
# <img src="./lecture_image/19_dlib_randmark.png" width=50%>

# %% [markdown]
# - Visual Studiio 다운로드 : https://visualstudio.microsoft.com/ko/downloads/
# - 실행 후에 C++를 이용한 데스크톱 개발를 선택하고 오른쪽의 선택된 옵션 (옵션을 보면, Windows용 C++ CMake 도구 선택)을 install 버튼을 클릭하여 설치

# %%
# 멀티플랫폼으로 사용할 수 있는 Make의 빌드관리시스템을 만들기 위한 오픈소스 프로젝트
# !pip install cmake
# Out:
# Collecting cmake
#   Downloading cmake-3.24.1.1-py2.py3-none-win_amd64.whl (39.7 MB)
#      --------------------------------------- 39.7/39.7 MB 23.4 MB/s eta 0:00:00
# Installing collected packages: cmake
# Successfully installed cmake-3.24.1.1
# WARNING: Ignoring invalid distribution -pencv-python (c:\anaconda3\envs\opencv2\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\anaconda3\envs\opencv2\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\anaconda3\envs\opencv2\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\anaconda3\envs\opencv2\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\anaconda3\envs\opencv2\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\anaconda3\envs\opencv2\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\anaconda3\envs\opencv2\lib\site-packages)

# %%
# !pip install dlib
# Out:
# Collecting dlib
#   Downloading dlib-19.24.0.tar.gz (3.2 MB)
#      ---------------------------------------- 3.2/3.2 MB 10.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: dlib
#   Building wheel for dlib (setup.py): started
#   Building wheel for dlib (setup.py): still running...
#   Building wheel for dlib (setup.py): still running...
#   Building wheel for dlib (setup.py): finished with status 'done'
#   Created wheel for dlib: filename=dlib-19.24.0-cp37-cp37m-win_amd64.whl size=2918069 sha256=0e04f22e2fb1c8b67119484333df1e5861607e76418c0dea3e4bd9a8bb65e1a2
#   Stored in directory: c:\users\gjaischool-56\appdata\local\pip\cache\wheels\33\2f\fb\0a707a1693b1f823c9755fc23143d787fa75ee3561d56e2bc5
# Successfully built dlib
# Installing collected packages: dlib
# Successfully installed dlib-19.24.0
# WARNING: Ignoring invalid distribution -pencv-python (c:\anaconda3\envs\opencv2\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\anaconda3\envs\opencv2\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\anaconda3\envs\opencv2\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\anaconda3\envs\opencv2\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\anaconda3\envs\opencv2\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\anaconda3\envs\opencv2\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\anaconda3\envs\opencv2\lib\site-packages)

# %%
# OpenCV가 제공하는 기능 중에 복잡하고 사용성이 떨어지는 부분을 보완 (비디오 스트림 파일 처리 등)
# !pip install imutils
# Out:
# Collecting imutils
#   Downloading imutils-0.5.4.tar.gz (17 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: imutils
#   Building wheel for imutils (setup.py): started
#   Building wheel for imutils (setup.py): finished with status 'done'
#   Created wheel for imutils: filename=imutils-0.5.4-py3-none-any.whl size=25847 sha256=1a4595f00e64f6182bf17467698ce54effeb0b2ae9d496cd31f85555cc6f67de
#   Stored in directory: c:\users\gjaischool-56\appdata\local\pip\cache\wheels\86\d7\0a\4923351ed1cec5d5e24c1eaf8905567b02a0343b24aa873df2
# Successfully built imutils
# Installing collected packages: imutils
# Successfully installed imutils-0.5.4
# WARNING: Ignoring invalid distribution -pencv-python (c:\anaconda3\envs\opencv2\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\anaconda3\envs\opencv2\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\anaconda3\envs\opencv2\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\anaconda3\envs\opencv2\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\anaconda3\envs\opencv2\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\anaconda3\envs\opencv2\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\anaconda3\envs\opencv2\lib\site-packages)

# %% [markdown]
# ## 랜드마크 검출

# %%
import dlib
import cv2
import matplotlib.pyplot as plt
import numpy as np
import imutils
from imutils import face_utils

# %%
# 모델 가져오기
detector = dlib.get_frontal_face_detector() # 정면 얼굴 인식기

# 68개의 랜드마크 검출
predictor = dlib.shape_predictor('model/shape_predictor_68_face_landmarks.dat')

img = cv2.imread('images/face2.jpg', cv2.IMREAD_COLOR)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img_gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

print(img.shape)


# 정면 얼굴 검출
rects = detector(img_gray, 1)

# (x1, y1, x2, y2)
print(rects)


# 검출한 얼굴에서 랜드마크를 검출
# enumerate(data) : data를 가져오면서 인덱스를 부여함
for (i, rect) in enumerate(rects):
    
    # 랜드마크 검출
    shape = predictor(img_gray, rect)
    
    # 랜드마크 좌표를 배열로 변환
    shape = face_utils.shape_to_np(shape)
    
    
#     print(shape) # 68개의 좌표가 나온다


    for (x, y) in shape:
        cv2.circle(img, (x, y), 5, (0, 0, 255), -1)
    
plt.imshow(img)
plt.axis('off')
# Out:
# (1024, 1024, 3)
# rectangles[[(233, 357) (788, 911)]]
# (-0.5, 1023.5, 1023.5, -0.5)

# %% [markdown]
# ## 얼굴에 스티커 붙이기
#
# - <font color=red>output = cv2.seamlessClone(src, dst, mask, center, flags)</font>
#   - src : 배경 이미지(dst)에 붙일 이미지
#   - dst : 배경 이미지
#   - mask : src를 붙일 dst의 위치 마스트, src의 크기여야 함
#   - center : src가 위치할 dst의 중심 위치
#   - flags : 동작 방법 (NORMAL_CLONE, MIXED_CLONE)

# %%
detector = dlib.get_frontal_face_detector()

predictor = dlib.shape_predictor('model/shape_predictor_68_face_landmarks.dat')

img = cv2.imread('images/face2.jpg', cv2.IMREAD_COLOR)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# 스티커 이미지와 크기를 맞추기 위해서 (500, 500) 크기로 이미지 크기를 변경
img = imutils.resize(img, width=500)
img_gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)


# 정면 얼굴 검출
rects = detector(img_gray, 1)

sticker = cv2.imread('images/cat-whisker2.png', cv2.IMREAD_COLOR)
sticker = cv2.cvtColor(sticker, cv2.COLOR_BGR2RGB)


# 검출한 얼굴에서 랜드마크를 검출
# enumerate(data) : data를 가져오면서 인덱스를 부여함
for (i, rect) in enumerate(rects):
    
    shape = predictor(img_gray, rect)
    shape = face_utils.shape_to_np(shape)
    
    # 얼굴 영역의 좌표를 가져온다
    (x, y, w, h) = face_utils.rect_to_bb(rect)
    
    # 스티커 이미지를 얼굴 영역에 맞게 조정 (높이만 절반으로 줄이자)
    sticker = cv2.resize(sticker, (w, h//2))
    
    # 얼굴에 들어갈 스티커의 마스크 생성 스티커와 같은 크기의 흰색 마스크
    mask = 255 * np.ones(sticker.shape, sticker.dtype)
    
    # 스티커를 붙일 때 기준이 되는 랜드마크 점을 설정 (29번 랜드마크)
    center = shape[29]
    
    # 스티커 붙이기
    img = cv2.seamlessClone(sticker, img, mask, center, cv2.MIXED_CLONE)
    
    
    
plt.imshow(img)
plt.axis('off')
# Out:
# (500, 500, 3)
# (-0.5, 499.5, 499.5, -0.5)

# %%
detector = dlib.get_frontal_face_detector()

predictor = dlib.shape_predictor('model/shape_predictor_68_face_landmarks.dat')

img = cv2.imread('images/face2.jpg', cv2.IMREAD_COLOR)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# 스티커 이미지와 크기를 맞추기 위해서 (500, 500) 크기로 이미지 크기를 변경
img = imutils.resize(img, width=500)
img_gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)


# 정면 얼굴 검출
rects = detector(img_gray, 1)

sticker = cv2.imread('images/ryan.PNG', cv2.IMREAD_COLOR)
sticker = cv2.cvtColor(sticker, cv2.COLOR_BGR2RGB)


# 검출한 얼굴에서 랜드마크를 검출
# enumerate(data) : data를 가져오면서 인덱스를 부여함
for (i, rect) in enumerate(rects):
    
    shape = predictor(img_gray, rect)
    shape = face_utils.shape_to_np(shape)
    
    # 얼굴 영역의 좌표를 가져온다
    (x, y, w, h) = face_utils.rect_to_bb(rect)
    
    # 스티커 이미지를 얼굴 영역에 맞게 조정 (높이만 절반으로 줄이자)
    sticker = cv2.resize(sticker, (w, h))
    
    # 얼굴에 들어갈 스티커의 마스크 생성 스티커와 같은 크기의 흰색 마스크
    mask = 255 * np.ones(sticker.shape, sticker.dtype)
    
    # 스티커를 붙일 때 기준이 되는 랜드마크 점을 설정 (29번 랜드마크)
    center = shape[12]
    
    # 스티커 붙이기
    img = cv2.seamlessClone(sticker, img, mask, center, cv2.MIXED_CLONE)
    
    
    
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 499.5, 499.5, -0.5)

# %% [markdown]
# ## ROI 영역 표시하기 (눈썹, 눈, 코, 입)

# %%
def visualize_facial_landmarks(image, shape, colors=None, alpha=0.75):
    overlay = image.copy()
    output = image.copy()
    
    # 색상 코드
    if colors is None:
        colors = [(19, 199, 109), (79, 76, 240), (230, 159, 23),
                  (168, 100, 168), (158, 163, 32), (163, 38, 32),
                  (180, 42, 220), (0, 0, 255)]

    # 랜드마크 영역을 하나씩 가져옴
    for (i, name) in enumerate(FACIAL_LANDMARKS_IDXS.keys()):
        # 랜드마크 좌표 (x, y)를 반환
        (j, k) = FACIAL_LANDMARKS_IDXS[name]
        pts = shape[j:k]

        # 턱선을 표시하는 경우
        if name == "jaw":
            #pass
            # 턱선 좌표를 가져와서 열린 곡선으로 턱선을 그림
            for l in range(1, len(pts)):
                ptA = tuple(pts[l - 1])
                ptB = tuple(pts[l])
                cv2.line(overlay, ptA, ptB, colors[i], 2)
        else:
            # 랜드마크 영역의 윤곽선을 추출
            hull = cv2.convexHull(pts)
            # 랜드마크 영역을 윤곽선으로 그림         
            cv2.drawContours(overlay, [hull], -1, colors[i], -1)

    # 투명도를 적용하여 랜드마크 영역을 색칠함
    # overlay * alpha + output * (1 - alpha) + 0 * output
    cv2.addWeighted(overlay, alpha, output, 1 - alpha, 0, output)
    
    return output

# %% [markdown]
# visualize_facial_landmarks() 함수를 변경하고자 하는 경우에 활용하기 위한 코드 (필요시 코드 배포)

# %%
# 표시하고자 하는 랜드마크만 따로 정의해서 사용
from collections import OrderedDict

# 68개의 랜드마크 번호
FACIAL_LANDMARKS_68_IDXS = OrderedDict([
    ("mouth", (48, 68)),            # 입
    ("inner_mouth", (60, 68)),      # 안쪽 입
    ("right_eyebrow", (17, 22)),    # 눈썹
    ("left_eyebrow", (22, 27)), 
    ("right_eye", (36, 42)),        # 눈
    ("left_eye", (42, 48)),
    ("nose", (27, 36)),             # 코
    ("jaw", (0, 17))                # 턱
])

FACIAL_LANDMARKS_EYE_IDXS = OrderedDict([
    ("right_eye", (36, 42)),
    ("left_eye", (42, 48))
])

FACIAL_LANDMARKS_IDXS = FACIAL_LANDMARKS_68_IDXS

# %%
# 실습

# %% [markdown]
# <table border=1 width=100%>
#     <tr><td style="border: 1px solid black; width:600px; height:40px; text-align: center;"><font size=4 color=blue><b>[19차시] 정리하기</b></font></td></tr>
#     <tr><td style="border: 1px solid black; text-align: left;"><font size=3>
# ○ dlib는 얼굴영상에서 68개의 얼굴의 랜드마크 검출<br><br>
# ○ <font color=red>output = cv2.seamlessClone(src, dst, mask, center, flags)</font> : 배경 이미지에 다른 이미지를 붙임
#         </font></td></tr>
# </table>
